# %% [markdown]
# import pandas as pd
#
# df = pd.read_csv('file location')
# df

# %% [markdown]
# # opening csv file from an URL

# %%
import pandas as pd
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv" # just copy paste url here
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# sep parameter
#
#
# pd.read_csv('movie_titles_metadata.tsv',sep='\t',names=['sno','name','release_year','rating','votes','genres'])
#
#
# index_col parameter # use that index as primary ones
#
# pd.read_csv('aug_train.csv',index_col='enrollee_id')
#
#
# HEADER PARAMETER
#
# pd.read_csv('test.csv',header=1)
#
# use_cols parameter # using only required column
#
# pd.read_csv('aug_train.csv',usecols= ['enrollee_id','gender','education_level'])
#
#
# Squeeze parameter # using only that columns
#
# pd.read_csv('aug_train.csv',usecols=['gender'],squeeze=True)
#
#
#
# Skiprows/nrows Parameter # skipping particular rows/ nrows is used to restrict the number of rows
# pd.read_csv('aug_train.csv',nrows=100) or pd.read_csv('file location',skiprows=[0,2,24]
#
#
#
# Encoding Parameter
# pd.read_csv('zomato.csv',encoding='latin-1')
#
#
# Skip bad lines # to eliminate(skip) the excessive columns  || error= parser
#
# pd.read_csv('BX-Books.csv', sep=';', encoding="latin-1",error_bad_lines=False)
#
#
# dtypes parameter # used to change the datatypes
# pd.read_csv('aug_train.csv',dtype={'target':int}).info()
#
#
# handling dates # to used the date fucntionality
# pd.read_csv('IPL Matches 2008-2020.csv',parse_dates=['date']).info()
#
#
# def rename(name):
#     if name == "Royal Challengers Bangalore":
#         return "RCB"
#     else:
#         return name
#
#
# Convertors
#
# pd.read_csv('IPL Matches 2008-2020.csv',converters={'team1':rename})
#
#
# na_values parameter
# pd.read_csv('aug_train.csv',na_values=['Male',])
#
# Loading a huge dataset in chunks
#
# dfs = pd.read_csv('aug_train.csv',chunksize=5000)
#
# for chunks in dfs:
#     print(chunk.shape)
